# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# This assignment uses a dataset of about 2239 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
root_path = 'gdrive/My Drive/Collab/MelanomaDetectionAssignment/'  #change dir to your project folder

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/gdrive/My Drive/Collab/MelanomaDetectionAssignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/")
data_dir_test = pathlib.Path('/content/gdrive/My Drive/Collab/MelanomaDetectionAssignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/')

# %%
print(data_dir_train)
print(data_dir_test)
# Out:
# /content/gdrive/My Drive/Collab/MelanomaDetectionAssignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train
# /content/gdrive/My Drive/Collab/MelanomaDetectionAssignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'training',
    image_size=(img_height,img_width),
    batch_size = batch_size
)

shape = tf.TensorShape([None,img_height,img_height,3])
print(shape)


val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'validation',
    image_size=(img_height,img_width),
    batch_size = batch_size
)

print(train_ds)
print(val_ds)


print(tf.keras.utils.image_dataset_from_directory(data_dir_train, labels='inferred'))
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.
# (None, 180, 180, 3)
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.
# <BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# Found 2239 files belonging to 9 classes.
# <BatchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset.
#
# #### Let's plot one instance of all the nine classes present in the training dataset

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize
plt.figure(figsize=(10,10))
for i in range(9): 
  plt.subplot(3, 3, i + 1)
  image = plt.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9 
model = Sequential()

model.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3)))   #Rescaling Layer

#First Convulation layer
model.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu',padding = 'Same'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Second Convulation Layer
model.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu',padding = 'Same'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Third Convulation Layer
model.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu',padding = 'Same'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Flatten Layer
##Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
model.add(layers.Flatten())

#Dense Layer
model.add(layers.Dense(128,activation='relu'))

#Dense Layer with softmax activation function.
#Softmax is an activation function that scales numbers/logits into probabilities.
model.add(layers.Dense(len(class_names),activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 61952)             0
#
#  dense (Dense)               (None, 128)               7929984
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 8,024,393
# Trainable params: 8,024,393
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **bold text**### Compile the model
# We are compiling our model with ```adam``` optimizer, Loss function  ```SparseCategoricalCrossentropy``` and metrics ```accuracy```

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 61952)             0
#
#  dense (Dense)               (None, 128)               7929984
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 8,024,393
# Trainable params: 8,024,393
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 56/56 [==============================] - 237s 873ms/step - loss: 1.8970 - accuracy: 0.3002 - val_loss: 1.7308 - val_accuracy: 0.3512
# Epoch 2/30
# 56/56 [==============================] - 2s 39ms/step - loss: 1.5910 - accuracy: 0.4431 - val_loss: 1.5308 - val_accuracy: 0.4362
# Epoch 3/30
# 56/56 [==============================] - 2s 40ms/step - loss: 1.4126 - accuracy: 0.5033 - val_loss: 1.3939 - val_accuracy: 0.5459
# Epoch 4/30
# 56/56 [==============================] - 2s 39ms/step - loss: 1.2725 - accuracy: 0.5497 - val_loss: 1.4109 - val_accuracy: 0.5235
# Epoch 5/30
# 56/56 [==============================] - 2s 40ms/step - loss: 1.2902 - accuracy: 0.5346 - val_loss: 1.4759 - val_accuracy: 0.4676
# Epoch 6/30
# 56/56 [==============================] - 2s 40ms/step - loss: 1.1602 - accuracy: 0.5871 - val_loss: 1.3437 - val_accuracy: 0.5459
# Epoch 7/30
# 56/56 [==============================] - 2s 40ms/step - loss: 1.0822 - accuracy: 0.6016 - val_loss: 1.4174 - val_accuracy: 0.5123
# Epoch 8/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.9798 - accuracy: 0.6462 - val_loss: 1.3907 - val_accuracy: 0.5526
# Epoch 9/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.9061 - accuracy: 0.6730 - val_loss: 1.4916 - val_accuracy: 0.5190
# Epoch 10/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.8937 - accuracy: 0.6830 - val_loss: 1.5812 - val_accuracy: 0.5280
# Epoch 11/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.7324 - accuracy: 0.7338 - val_loss: 1.6066 - val_accuracy: 0.5548
# Epoch 12/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.7839 - accuracy: 0.7109 - val_loss: 1.7506 - val_accuracy: 0.5101
# Epoch 13/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.6624 - accuracy: 0.7729 - val_loss: 1.9546 - val_accuracy: 0.5324
# Epoch 14/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.5624 - accuracy: 0.7930 - val_loss: 1.8835 - val_accuracy: 0.4989
# Epoch 15/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.5180 - accuracy: 0.8147 - val_loss: 1.8416 - val_accuracy: 0.5526
# Epoch 16/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.4895 - accuracy: 0.8203 - val_loss: 2.2735 - val_accuracy: 0.5503
# Epoch 17/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.4541 - accuracy: 0.8248 - val_loss: 2.2131 - val_accuracy: 0.5190
# Epoch 18/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.4248 - accuracy: 0.8482 - val_loss: 2.4546 - val_accuracy: 0.4877
# Epoch 19/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.3699 - accuracy: 0.8544 - val_loss: 2.6281 - val_accuracy: 0.5168
# Epoch 20/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.3227 - accuracy: 0.8811 - val_loss: 2.5539 - val_accuracy: 0.5145
# Epoch 21/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.3249 - accuracy: 0.8756 - val_loss: 2.2242 - val_accuracy: 0.5324
# Epoch 22/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.2570 - accuracy: 0.8979 - val_loss: 3.0911 - val_accuracy: 0.5123
# Epoch 23/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.2580 - accuracy: 0.8912 - val_loss: 2.3958 - val_accuracy: 0.5526
# Epoch 24/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.2718 - accuracy: 0.8867 - val_loss: 2.8588 - val_accuracy: 0.5101
# Epoch 25/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.2317 - accuracy: 0.9068 - val_loss: 2.7704 - val_accuracy: 0.5235
# Epoch 26/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.1723 - accuracy: 0.9180 - val_loss: 2.6879 - val_accuracy: 0.5280
# Epoch 27/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.1434 - accuracy: 0.9364 - val_loss: 2.4770 - val_accuracy: 0.5324
# Epoch 28/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.1587 - accuracy: 0.9235 - val_loss: 2.9318 - val_accuracy: 0.5145
# Epoch 29/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.1437 - accuracy: 0.9291 - val_loss: 2.9759 - val_accuracy: 0.5302
# Epoch 30/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.1284 - accuracy: 0.9358 - val_loss: 2.9022 - val_accuracy: 0.5078

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here
# Finding on the first base model
#
# The model is clearly overfitting because:
# 1. We can see the difference in loss functions in training & test.
#
# 2. The accuracy on training set is around 92% because there are enough features to remember the pattern while validation accuracy is around 53%.

# %%
# The model is clearly overfitting. Now we will choose an appropriate data augumentation strategy. 

data_augument = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
# We will see how our training images look after we apply augmentation.We will visualize one instance for each of the 9 classes.

plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_augument(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
### Next we will create our second CNN model on this augmented dataset. To reduce overfitting, we will add two dropout layers with 25% dropouts and see if it works.

# %%
### Your code goes here
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9 
#model = Sequential()
model = Sequential([ data_augument,
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
#model.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3)))   #Rescaling Layer

#First Convulation layer
model.add(layers.Conv2D(32,kernel_size=(3,3),padding = 'Same',activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Second Convulation Layer
model.add(layers.Conv2D(64,kernel_size=(3,3),padding = 'Same',activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Third Convulation Layer
model.add(layers.Conv2D(128,kernel_size=(3,3),padding = 'Same',activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Dropout layer with 50% Fraction of the input units to drop.
model.add(layers.Dropout(0.3))

#Flatten Layer
##Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
model.add(layers.Flatten())

#Dense Layer
model.add(layers.Dense(128,activation='relu'))

#Dropout layer with 25% Fraction of the input units to drop.
model.add(layers.Dropout(0.3))

#Dense Layer with softmax activation function.
#Softmax is an activation function that scales numbers/logits into probabilities.
model.add(layers.Dense(len(class_names),activation='softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 180, 180, 32)      896
#
#  max_pooling2d_3 (MaxPooling  (None, 90, 90, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 90, 90, 64)        18496
#
#  max_pooling2d_4 (MaxPooling  (None, 45, 45, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 45, 45, 128)       73856
#
#  max_pooling2d_5 (MaxPooling  (None, 22, 22, 128)      0
#  2D)
#
#  dropout (Dropout)           (None, 22, 22, 128)       0
#
#  flatten_1 (Flatten)         (None, 61952)             0
#
#  dense_2 (Dense)             (None, 128)               7929984
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 8,024,393
# Trainable params: 8,024,393
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs=30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 56/56 [==============================] - 4s 47ms/step - loss: 2.2929 - accuracy: 0.2545 - val_loss: 1.8285 - val_accuracy: 0.3982
# Epoch 2/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.7500 - accuracy: 0.3683 - val_loss: 1.6547 - val_accuracy: 0.4362
# Epoch 3/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.6203 - accuracy: 0.4286 - val_loss: 1.6364 - val_accuracy: 0.4273
# Epoch 4/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.5289 - accuracy: 0.4637 - val_loss: 1.5976 - val_accuracy: 0.4541
# Epoch 5/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.5711 - accuracy: 0.4459 - val_loss: 1.4858 - val_accuracy: 0.4989
# Epoch 6/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.4536 - accuracy: 0.4883 - val_loss: 1.4445 - val_accuracy: 0.4855
# Epoch 7/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.4687 - accuracy: 0.4838 - val_loss: 1.4383 - val_accuracy: 0.4966
# Epoch 8/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.4166 - accuracy: 0.5000 - val_loss: 1.5635 - val_accuracy: 0.4676
# Epoch 9/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.3922 - accuracy: 0.5134 - val_loss: 1.4031 - val_accuracy: 0.5347
# Epoch 10/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.3687 - accuracy: 0.5134 - val_loss: 1.4113 - val_accuracy: 0.5280
# Epoch 11/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.3703 - accuracy: 0.5156 - val_loss: 1.5109 - val_accuracy: 0.4922
# Epoch 12/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.3520 - accuracy: 0.5173 - val_loss: 1.4101 - val_accuracy: 0.5280
# Epoch 13/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.3440 - accuracy: 0.5240 - val_loss: 1.3415 - val_accuracy: 0.5436
# Epoch 14/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.3195 - accuracy: 0.5251 - val_loss: 1.4384 - val_accuracy: 0.5235
# Epoch 15/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.3077 - accuracy: 0.5396 - val_loss: 1.5078 - val_accuracy: 0.4855
# Epoch 16/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.3812 - accuracy: 0.5039 - val_loss: 1.4568 - val_accuracy: 0.4922
# Epoch 17/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.2714 - accuracy: 0.5385 - val_loss: 1.4264 - val_accuracy: 0.5190
# Epoch 18/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.3135 - accuracy: 0.5240 - val_loss: 1.5263 - val_accuracy: 0.4810
# Epoch 19/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.2779 - accuracy: 0.5430 - val_loss: 1.3395 - val_accuracy: 0.5436
# Epoch 20/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.3095 - accuracy: 0.5363 - val_loss: 1.3517 - val_accuracy: 0.5503
# Epoch 21/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.2419 - accuracy: 0.5552 - val_loss: 1.5171 - val_accuracy: 0.5011
# Epoch 22/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.2398 - accuracy: 0.5569 - val_loss: 1.3126 - val_accuracy: 0.5235
# Epoch 23/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.2335 - accuracy: 0.5446 - val_loss: 1.4467 - val_accuracy: 0.5168
# Epoch 24/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.2038 - accuracy: 0.5714 - val_loss: 1.2921 - val_accuracy: 0.5459
# Epoch 25/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.2447 - accuracy: 0.5552 - val_loss: 1.3025 - val_accuracy: 0.5414
# Epoch 26/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.2356 - accuracy: 0.5430 - val_loss: 1.4204 - val_accuracy: 0.5235
# Epoch 27/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.2446 - accuracy: 0.5497 - val_loss: 1.4852 - val_accuracy: 0.5235
# Epoch 28/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.2092 - accuracy: 0.5675 - val_loss: 1.3460 - val_accuracy: 0.5548
# Epoch 29/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.1872 - accuracy: 0.5614 - val_loss: 1.3538 - val_accuracy: 0.5145
# Epoch 30/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.2061 - accuracy: 0.5642 - val_loss: 1.3396 - val_accuracy: 0.5638

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?
# Finding from Second Model
#
# There is a significant drop in accuracy but we can definitely see the overfitting problem has solved due to data augmentation.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
##
path_list=[]
lesion_list=[]
for i in class_names:
      
    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/gdrive/My Drive/Collab/MelanomaDetect...  actinic keratosis
# 1     /content/gdrive/My Drive/Collab/MelanomaDetect...  actinic keratosis
# 2     /content/gdrive/My Drive/Collab/MelanomaDetect...  actinic keratosis
# 3     /content/gdrive/My Drive/Collab/MelanomaDetect...  actinic keratosis
# 4     /content/gdrive/My Drive/Collab/MelanomaDetect...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/gdrive/My Drive/Collab/MelanomaDetect...    vascular lesion
# 2235  /content/gdrive/My Drive/Collab/MelanomaDetect...    vascular lesion
# 2236  /content/gdrive/My Drive/Collab/MelanomaDetect...    vascular lesion
# 2237  /content/gdrive/My Drive/Collab/MelanomaDetect...    vascular lesion
# 2238  /content/gdrive/My Drive/Collab/MelanomaDetect...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
count=[]
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(class_names,count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #### - Which classes dominate the data in terms proportionate number of samples?
# Answer-1 :- Seborrheic keratosis has least number of samples
#
# Answer-2:- Pigmented benign keratosis have highest number of classes  followed by Melanoma.

# %%
class_names
# Out:
# ['actinic keratosis',
#  'basal cell carcinoma',
#  'dermatofibroma',
#  'melanoma',
#  'nevus',
#  'pigmented benign keratosis',
#  'seborrheic keratosis',
#  'squamous cell carcinoma',
#  'vascular lesion']

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.0)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="/content/gdrive/My Drive/Collab/MelanomaDetectionAssignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset+i ,save_format='jpg')
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/My Drive/Collab/MelanomaDetectionAssignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FC94C0AAAD0>: 100%|██████████| 500/500 [00:08<00:00, 56.16 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/My Drive/Collab/MelanomaDetectionAssignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FC94C249BD0>: 100%|██████████| 500/500 [00:09<00:00, 54.10 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/My Drive/Collab/MelanomaDetectionAssignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FC94C0DC150>: 100%|██████████| 500/500 [00:08<00:00, 56.11 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/My Drive/Collab/MelanomaDetectionAssignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FC9D00E3290>: 100%|██████████| 500/500 [00:43<00:00, 11.46 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/My Drive/Collab/MelanomaDetectionAssignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=767x576 at 0x7FC94C1E01D0>: 100%|██████████| 500/500 [00:36<00:00, 13.79 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/My Drive/Collab/MelanomaDetectionAssignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FC93F998710>: 100%|██████████| 500/500 [00:09<00:00, 55.39 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/My Drive/Collab/MelanomaDetectionAssignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FC94C1A8D50>: 100%|██████████| 500/500 [00:21<00:00, 23.72 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/My Drive/Collab/MelanomaDetectionAssignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FC94CC42E10>: 100%|██████████| 500/500 [00:09<00:00, 54.38 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/My Drive/Collab/MelanomaDetectionAssignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FC94CED5C50>: 100%|██████████| 500/500 [00:09<00:00, 54.78 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
#data_dir_train1 = pathlib.Path("/content/gdrive/My Drive/Collab/MelanomaDetectionAssignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output/")

image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
for i in class_names:
      
    for j in data_dir_train.glob(i+'/output/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
new_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
new_df
# Out:
#                                                    Path              Label
# 0     /content/gdrive/My Drive/Collab/MelanomaDetect...  actinic keratosis
# 1     /content/gdrive/My Drive/Collab/MelanomaDetect...  actinic keratosis
# 2     /content/gdrive/My Drive/Collab/MelanomaDetect...  actinic keratosis
# 3     /content/gdrive/My Drive/Collab/MelanomaDetect...  actinic keratosis
# 4     /content/gdrive/My Drive/Collab/MelanomaDetect...  actinic keratosis
# ...                                                 ...                ...
# 6734  /content/gdrive/My Drive/Collab/MelanomaDetect...    vascular lesion
# 6735  /content/gdrive/My Drive/Collab/MelanomaDetect...    vascular lesion
# 6736  /content/gdrive/My Drive/Collab/MelanomaDetect...    vascular lesion
# 6737  /content/gdrive/My Drive/Collab/MelanomaDetect...    vascular lesion
# 6738  /content/gdrive/My Drive/Collab/MelanomaDetect...    vascular lesion
#
# [6739 rows x 2 columns]

# %%
new_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    962
# melanoma                      938
# basal cell carcinoma          876
# nevus                         857
# squamous cell carcinoma       681
# vascular lesion               639
# actinic keratosis             614
# dermatofibroma                595
# seborrheic keratosis          577
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
data_dir_train1 = pathlib.Path("/content/gdrive/My Drive/Collab/MelanomaDetectionAssignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/")
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train1,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train1,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
from keras.layers import BatchNormalization

model = Sequential()

model.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3)))   #Rescaling Layer

#First Convulation layer
model.add(layers.Conv2D(32,kernel_size=(3,3),padding = 'Same',activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Dropout(0.25))

#Second Convulation Layer
model.add(layers.Conv2D(64,kernel_size=(3,3),padding = 'Same',activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Dropout(0.25))

#Third Convulation Layer
model.add(layers.Conv2D(128,kernel_size=(3,3),padding = 'Same',activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Dropout layer with 25% Fraction of the input units to drop.
model.add(layers.Dropout(0.25))

#Flatten Layer
##Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
model.add(layers.Flatten())

#Dense Layer
model.add(layers.Dense(128,activation='relu'))
model.add(BatchNormalization())

#Dropout layer with 25% Fraction of the input units to drop.
model.add(layers.Dropout(0.25))

#Dense Layer with softmax activation function.
#Softmax is an activation function that scales numbers/logits into probabilities.
model.add(layers.Dense(len(class_names),activation='softmax'))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 180, 180, 32)      896
#
#  max_pooling2d_6 (MaxPooling  (None, 90, 90, 32)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 90, 90, 32)        0
#
#  conv2d_7 (Conv2D)           (None, 90, 90, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 45, 45, 64)       0
#  2D)
#
#  dropout_3 (Dropout)         (None, 45, 45, 64)        0
#
#  conv2d_8 (Conv2D)           (None, 45, 45, 128)       73856
#
#  max_pooling2d_8 (MaxPooling  (None, 22, 22, 128)      0
#  2D)
#
#  dropout_4 (Dropout)         (None, 22, 22, 128)       0
#
#  flatten_2 (Flatten)         (None, 61952)             0
#
#  dense_4 (Dense)             (None, 128)               7929984
#
#  batch_normalization (BatchN  (None, 128)              512
#  ormalization)
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 8,024,905
# Trainable params: 8,024,649
# Non-trainable params: 256
# _________________________________________________________________

# %%
# vizualizing the model 
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs =40
## Your code goes here, use 50 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/40
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 169/169 [==============================] - 29s 66ms/step - loss: 1.8150 - accuracy: 0.3348 - val_loss: 3.2519 - val_accuracy: 0.2977
# Epoch 2/40
# 169/169 [==============================] - 7s 44ms/step - loss: 1.5283 - accuracy: 0.4420 - val_loss: 2.5017 - val_accuracy: 0.2494
# Epoch 3/40
# 169/169 [==============================] - 7s 44ms/step - loss: 1.3890 - accuracy: 0.4957 - val_loss: 1.5449 - val_accuracy: 0.3883
# Epoch 4/40
# 169/169 [==============================] - 7s 44ms/step - loss: 1.2807 - accuracy: 0.5276 - val_loss: 1.9400 - val_accuracy: 0.3237
# Epoch 5/40
# 169/169 [==============================] - 7s 44ms/step - loss: 1.1726 - accuracy: 0.5734 - val_loss: 1.5964 - val_accuracy: 0.4358
# Epoch 6/40
# 169/169 [==============================] - 8s 45ms/step - loss: 1.1018 - accuracy: 0.5987 - val_loss: 1.4206 - val_accuracy: 0.4469
# Epoch 7/40
# 169/169 [==============================] - 7s 44ms/step - loss: 1.0583 - accuracy: 0.6183 - val_loss: 1.3652 - val_accuracy: 0.4766
# Epoch 8/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.9322 - accuracy: 0.6695 - val_loss: 1.1249 - val_accuracy: 0.5776
# Epoch 9/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.8673 - accuracy: 0.6868 - val_loss: 1.0292 - val_accuracy: 0.6110
# Epoch 10/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.7903 - accuracy: 0.7157 - val_loss: 1.1391 - val_accuracy: 0.5627
# Epoch 11/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.6905 - accuracy: 0.7507 - val_loss: 1.0993 - val_accuracy: 0.5895
# Epoch 12/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.5972 - accuracy: 0.7878 - val_loss: 0.9617 - val_accuracy: 0.6288
# Epoch 13/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.5164 - accuracy: 0.8118 - val_loss: 0.8893 - val_accuracy: 0.6667
# Epoch 14/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.4744 - accuracy: 0.8318 - val_loss: 0.8079 - val_accuracy: 0.7008
# Epoch 15/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.4142 - accuracy: 0.8576 - val_loss: 0.7713 - val_accuracy: 0.7201
# Epoch 16/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.3375 - accuracy: 0.8765 - val_loss: 0.7032 - val_accuracy: 0.7327
# Epoch 17/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.3206 - accuracy: 0.8811 - val_loss: 0.6197 - val_accuracy: 0.8070
# Epoch 18/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.2777 - accuracy: 0.9043 - val_loss: 0.7297 - val_accuracy: 0.7565
# Epoch 19/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.2483 - accuracy: 0.9099 - val_loss: 0.6315 - val_accuracy: 0.7899
# Epoch 20/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.2191 - accuracy: 0.9197 - val_loss: 0.7862 - val_accuracy: 0.7528
# Epoch 21/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.2031 - accuracy: 0.9258 - val_loss: 0.5719 - val_accuracy: 0.8159
# Epoch 22/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.2048 - accuracy: 0.9271 - val_loss: 0.7538 - val_accuracy: 0.7847
# Epoch 23/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.2023 - accuracy: 0.9267 - val_loss: 0.6070 - val_accuracy: 0.8018
# Epoch 24/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.1690 - accuracy: 0.9401 - val_loss: 0.6673 - val_accuracy: 0.8010
# Epoch 25/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.1752 - accuracy: 0.9364 - val_loss: 0.6298 - val_accuracy: 0.7988
# Epoch 26/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.1651 - accuracy: 0.9381 - val_loss: 0.6377 - val_accuracy: 0.8085
# Epoch 27/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.1538 - accuracy: 0.9410 - val_loss: 0.6870 - val_accuracy: 0.8003
# Epoch 28/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.1408 - accuracy: 0.9516 - val_loss: 0.6571 - val_accuracy: 0.8218
# Epoch 29/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.1278 - accuracy: 0.9542 - val_loss: 0.6352 - val_accuracy: 0.8330
# Epoch 30/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.1439 - accuracy: 0.9484 - val_loss: 0.7487 - val_accuracy: 0.7973
# Epoch 31/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.1302 - accuracy: 0.9494 - val_loss: 0.6925 - val_accuracy: 0.8077
# Epoch 32/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.1145 - accuracy: 0.9592 - val_loss: 0.7669 - val_accuracy: 0.7906
# Epoch 33/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.1173 - accuracy: 0.9566 - val_loss: 0.6937 - val_accuracy: 0.8129
# Epoch 34/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.1094 - accuracy: 0.9598 - val_loss: 0.7098 - val_accuracy: 0.8085
# Epoch 35/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.1060 - accuracy: 0.9599 - val_loss: 0.6552 - val_accuracy: 0.8233
# Epoch 36/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.1107 - accuracy: 0.9646 - val_loss: 0.6893 - val_accuracy: 0.8159
# Epoch 37/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.0968 - accuracy: 0.9649 - val_loss: 0.7477 - val_accuracy: 0.7929
# Epoch 38/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.1292 - accuracy: 0.9520 - val_loss: 0.6803 - val_accuracy: 0.8166
# Epoch 39/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.1037 - accuracy: 0.9629 - val_loss: 0.7260 - val_accuracy: 0.7914
# Epoch 40/40
# 169/169 [==============================] - 7s 44ms/step - loss: 0.1278 - accuracy: 0.9575 - val_loss: 0.6952 - val_accuracy: 0.8070

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
#  Training accuracy is 97% and validation accuracy is around 80%.Accuracy on training data has increased by using Augmentor library but model is still overfitting
#
# The problem of overfitting can be further solved by adding more layers,neurons or adding dropout layers.
